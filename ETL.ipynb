# %%
import pandas as pd
# from URL
dfs = pd.read_html("https://docs.google.com/spreadsheets/d/e/2PACX-1vQlEs3FxFPwm-dpvU1YdsfRgsbfT9WdiXJHZm9kJgGTziPnk-y3TWtftbSbxj6Fe_g0NxYgqyVHTVU5/pubhtml?gid=1397577608&amp;single=true&amp;widget=true&amp;headers=false") 
df = dfs [0]
new_header = df.iloc[0] #grab the first row for the header
df = df[1:] #take the data less the header row
df.columns = new_header #set the header row as the df header
df.drop(df.columns[[0]], axis=1, inplace=True)
df
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# 0         retrived_at province_id               city  \
# 1   5/2/2023 10:15:27       TH-10        Phra Nakhon
# 2   5/2/2023 10:15:59       TH-11          Bang Phli
# 3   5/2/2023 10:16:30       TH-12  Mueang Nonthaburi
# 4   5/2/2023 10:17:01       TH-13       Khlong Luang
# 5   5/2/2023 10:17:32       TH-14          Ayutthaya
# ..                ...         ...                ...
# 62  5/2/2023 15:18:32       TH-16             Ban Mi
# 63  5/2/2023 15:19:03       TH-20           Na Kluea
# 64  5/2/2023 15:19:34       TH-21           Ban Khai
# 65  5/2/2023 15:20:05       TH-50         Chiang Mai
# 66  5/2/2023 15:20:36       TH-52          Hang Chat
#
# 0                      state   country pollution_aqi polution_main weather_tp  \
# 1                    Bangkok  Thailand            86            p2         35
# 2               Samut Prakan  Thailand            63            p2         33
# 3                 Nonthaburi  Thailand            88            p2         34
# 4               Pathum Thani  Thailand            76            p2         34
# 5   Phra Nakhon Si Ayutthaya  Thailand            92            p2         32
# ..                       ...       ...           ...           ...        ...
# 62                  Lop Buri  Thailand            64            p2         38
# 63                 Chon Buri  Thailand            68            p2         32
# 64                    Rayong  Thailand            42            p2         32
# 65                Chiang Mai  Thailand            68            p2         37
# 66                   Lampang  Thailand            86            p2         32
#
# 0  weather_pr weather_hu weather_ws weather_wd
# 1        1010         49       3.02        193
# 2        1011         66       1.54          0
# 3        1011         58       2.06        160
# 4        1011         75       2.06        160
# 5        1010         50       2.93        193
# ..        ...        ...        ...        ...
# 62       1005         32       4.39        178
# 63       1007         65       5.47        213
# 64       1008         68       4.28        187
# 65       1007         30        3.6        190
# 66       1007         56       1.86        307
#
# [66 rows x 12 columns]

# %%
df.to_csv('result.csv', index=False)
